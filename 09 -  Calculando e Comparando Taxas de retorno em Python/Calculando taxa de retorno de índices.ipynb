# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC', '^IXIC', '^GDAXI', '^DJI']

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo', start='1997-1-1')['Adj Close']
# Out:
#   File "<ipython-input-14-032847ed96f5>", line 1
#     tickers = ['^GSPC' as 'Nasdaq', '^IXIC', '^GDAXI', '^DJI']
#                         ^
# SyntaxError: invalid syntax

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI         ^DJI
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059  6442.490234
# 1997-01-03  748.030029  1310.680054  2863.260010  6544.089844
# 1997-01-06  747.650024  1316.400024  2890.199951  6567.180176
# 1997-01-07  753.229980  1327.729980  2876.340088  6600.660156
# 1997-01-08  748.409973  1320.349976  2904.080078  6549.479980

# %%
ind_data.tail()
# Out:
#                   ^GSPC         ^IXIC        ^GDAXI          ^DJI
# Date
# 2020-10-19  3426.919922  11478.879883  12854.660156  28195.419922
# 2020-10-20  3443.120117  11516.490234  12736.950195  28308.789062
# 2020-10-21  3435.560059  11484.690430  12557.639648  28210.820312
# 2020-10-22  3453.489990  11506.009766  12543.059570  28363.660156
# 2020-10-23  3457.330078  11510.324219  12645.750000  28297.169922

# %%
(ind_data/ind_data.iloc[0]*100).plot(figsize=(15,6));
plt.show()

# %%
ind_returns = (ind_data/ind_data.shift(1)) - 1
ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI      ^DJI
# Date
# 2020-10-19 -0.016330 -0.016508 -0.004209 -0.014364
# 2020-10-20  0.004727  0.003276 -0.009157  0.004021
# 2020-10-21 -0.002196 -0.002761 -0.014078 -0.003461
# 2020-10-22  0.005219  0.001856 -0.001161  0.005418
# 2020-10-23  0.001112  0.000375  0.008187 -0.002344

# %%
annual_ind_returns = ind_returns.mean()*250
annual_ind_returns
# Out:
# ^GSPC     0.083951
# ^IXIC     0.123459
# ^GDAXI    0.076054
# ^DJI      0.079779
# dtype: float64

# %%
#Comparando a APPL com os índices
tickers = ['PG', '^GSPC', '^DJI']

data_2 = pd.DataFrame()

for t in tickers:
    data_2[t] = wb.DataReader(t, data_source='yahoo', start='2007-1-1')['Adj Close']

# %%
data_2.tail()
# Out:
#                     PG        ^GSPC          ^DJI
# Date
# 2020-10-19  141.126404  3426.919922  28195.419922
# 2020-10-20  141.693237  3443.120117  28308.789062
# 2020-10-21  142.459000  3435.560059  28210.820312
# 2020-10-22  141.449997  3453.489990  28363.660156
# 2020-10-23  142.619293  3456.679932  28292.619141

# %%
(data_2/data_2.iloc[0]*100).plot(figsize=(15,6));
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
